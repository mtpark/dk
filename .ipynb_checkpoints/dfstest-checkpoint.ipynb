# %%
import dfs

# %%
dfs.df.head()
# Out:
#                 Position  Salary Team  Opp  \
# Name
# Dak Prescott          QB    4000  DAL  WAS
# Jordan Reed           TE    2500   SF   NE
# Rex Burkhead          RB    4000   NE   SF
# Anthony Firkser       TE    3000  TEN  PIT
# Cedrick Wilson        WR    3300  DAL  WAS
#
#                                           All Scores  Best Score  Best / Sal
# Name
# Dak Prescott     [17.6, 39.8, 29.5, 38.3, 14.4, nan]        39.8        9.95
# Jordan Reed          [3.2, 24.0, 4.3, nan, nan, nan]        24.0        9.60
# Rex Burkhead         [3.2, 8.9, 34.8, 6.0, nan, 1.4]        34.8        8.70
# Anthony Firkser      [2.5, 8.5, 0.0, nan, 4.9, 25.3]        25.3        8.43
# Cedrick Wilson      [0.0, 0.0, 27.7, 6.4, 10.6, 3.0]        27.7        8.39
