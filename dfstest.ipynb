# %%
import dfs as dfs

# %%
dfs.df[dfs.df['Position'] == 'TE'][:20]
# Out:
#                 Position  Salary Team  Opp  \
# Name
# Jordan Reed           TE    2500   SF   NE
# Anthony Firkser       TE    3000  TEN  PIT
# Robert Tonyan         TE    4600   GB  HOU
# George Kittle         TE    6500   SF   NE
# Tyler Kroft           TE    3100  BUF  NYJ
# C.J. Uzomah           TE    2500  CIN  CLE
# O.J. Howard           TE    2500   TB   LV
# Dalton Schultz        TE    3900  DAL  WAS
# Jonnu Smith           TE    4700  TEN  PIT
# Darren Fells          TE    4100  HOU   GB
# Jesse James           TE    2500  DET  ATL
# David Njoku           TE    3000  CLE  CIN
# Darren Waller         TE    6100   LV   TB
# Foster Moreau         TE    2500   LV   TB
# Tyler Eifert          TE    3000  JAC  LAC
# Hayden Hurst          TE    4400  ATL  DET
# Rob Gronkowski        TE    4600   TB   LV
# Eric Ebron            TE    4000  PIT  TEN
# Noah Fant             TE    4800  DEN   KC
# Travis Kelce          TE    6300   KC  DEN
#
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
